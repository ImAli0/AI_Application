# %% [markdown]
# <a href="https://colab.research.google.com/github/ImAli0/ImAli/blob/main/week9/week9_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.layers import Dropout

import numpy as np 
import logging 
tf.get_logger().setLevel(logging.ERROR) 
EPOCHS = 500 
BATCH_SIZE = 16 
# Read and standardize the data. 
boston_housing = keras.datasets.boston_housing 
(raw_x_train, y_train), (raw_x_test, y_test) = boston_housing.load_data() 
x_mean = np.mean(raw_x_train, axis=0) 
x_stddev = np.std(raw_x_train, axis= 0) 
x_train =(raw_x_train - x_mean) / x_stddev 
x_test =(raw_x_test - x_mean) / x_stddev

# %%
# Create and train model. 
model = Sequential() 
model.add(Dense(128, activation='relu', input_shape=[13])) 
model.add(Dropout(0.3)) 
model.add(Dense(128, activation='relu')) 
model.add(Dropout(0.3)) 
model.add(Dense(64, activation='relu') )
model.add(Dropout(0.3)) 
model.add(Dense(1, activation='linear')) 
model.compile(loss='mean_squared_error', optimizer='adam', metrics ='mean_absolute_error') 
model.summary() 
history = model.fit(x_train, y_train, validation_data=( x_test, y_test), epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2, shuffle=True) 
# Print first 4 predictions. 
predictions = model.predict(x_test) 
for i in range(0, 4): 
  print('Prediction: ', predictions[i, 0], ', true value: ', y_test[i])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_23 (Dense)            (None, 128)               1792
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_24 (Dense)            (None, 128)               16512
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 26,625
# Trainable params: 26,625
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 26/26 - 1s - loss: 452.6816 - mean_absolute_error: 19.1744 - val_loss: 257.0547 - val_mean_absolute_error: 13.8442 - 783ms/epoch - 30ms/step
# Epoch 2/500
# 26/26 - 0s - loss: 121.1853 - mean_absolute_error: 8.4953 - val_loss: 54.1051 - val_mean_absolute_error: 5.6051 - 100ms/epoch - 4ms/step
# Epoch 3/500
# 26/26 - 0s - loss: 50.6228 - mean_absolute_error: 5.4627 - val_loss: 27.2499 - val_mean_absolute_error: 4.0184 - 92ms/epoch - 4ms/step
# Epoch 4/500
# 26/26 - 0s - loss: 41.8691 - mean_absolute_error: 4.6875 - val_loss: 29.7108 - val_mean_absolute_error: 4.1193 - 86ms/epoch - 3ms/step
# Epoch 5/500
# 26/26 - 0s - loss: 33.9343 - mean_absolute_error: 4.3406 - val_loss: 27.9255 - val_mean_absolute_error: 3.8580 - 86ms/epoch - 3ms/step
# Epoch 6/500
# 26/26 - 0s - loss: 36.3458 - mean_absolute_error: 4.5080 - val_loss: 27.0977 - val_mean_absolute_error: 3.8303 - 83ms/epoch - 3ms/step
# Epoch 7/500
# 26/26 - 0s - loss: 35.2196 - mean_absolute_error: 4.3544 - val_loss: 26.7774 - val_mean_absolute_error: 3.6845 - 103ms/epoch - 4ms/step
# Epoch 8/500
# 26/26 - 0s - loss: 29.4785 - mean_absolute_error: 4.1888 - val_loss: 27.5698 - val_mean_absolute_error: 3.6116 - 87ms/epoch - 3ms/step
# Epoch 9/500
# 26/26 - 0s - loss: 29.7261 - mean_absolute_error: 4.1389 - val_loss: 28.8764 - val_mean_absolute_error: 3.9525 - 86ms/epoch - 3ms/step
# Epoch 10/500
# 26/26 - 0s - loss: 29.6157 - mean_absolute_error: 4.2151 - val_loss: 26.0542 - val_mean_absolute_error: 3.6538 - 97ms/epoch - 4ms/step
# Epoch 11/500
# 26/26 - 0s - loss: 32.4215 - mean_absolute_error: 4.2443 - val_loss: 25.6568 - val_mean_absolute_error: 3.5257 - 118ms/epoch - 5ms/step
# Epoch 12/500
# 26/26 - 0s - loss: 31.3855 - mean_absolute_error: 4.3170 - val_loss: 25.4924 - val_mean_absolute_error: 3.6343 - 99ms/epoch - 4ms/step
# Epoch 13/500
# 26/26 - 0s - loss: 28.0565 - mean_absolute_error: 3.9580 - val_loss: 26.3569 - val_mean_absolute_error: 3.6030 - 98ms/epoch - 4ms/step
# Epoch 14/500
# 26/26 - 0s - loss: 24.8531 - mean_absolute_error: 3.8674 - val_loss: 24.3936 - val_mean_absolute_error: 3.4124 - 89ms/epoch - 3ms/step
# Epoch 15/500
# 26/26 - 0s - loss: 25.8945 - mean_absolute_error: 3.8239 - val_loss: 28.1920 - val_mean_absolute_error: 3.7501 - 87ms/epoch - 3ms/step
# Epoch 16/500
# 26/26 - 0s - loss: 24.3197 - mean_absolute_error: 3.7655 - val_loss: 26.8261 - val_mean_absolute_error: 3.3993 - 96ms/epoch - 4ms/step
# Epoch 17/500
# 26/26 - 0s - loss: 25.5833 - mean_absolute_error: 3.8979 - val_loss: 25.3662 - val_mean_absolute_error: 3.2400 - 85ms/epoch - 3ms/step
# Epoch 18/500
# 26/26 - 0s - loss: 23.3110 - mean_absolute_error: 3.7171 - val_loss: 24.8965 - val_mean_absolute_error: 3.2054 - 96ms/epoch - 4ms/step
# Epoch 19/500
# 26/26 - 0s - loss: 28.6927 - mean_absolute_error: 4.0017 - val_loss: 26.8306 - val_mean_absolute_error: 3.5268 - 89ms/epoch - 3ms/step
# Epoch 20/500
# 26/26 - 0s - loss: 26.7131 - mean_absolute_error: 3.8771 - val_loss: 28.2339 - val_mean_absolute_error: 3.6567 - 95ms/epoch - 4ms/step
# Epoch 21/500
# 26/26 - 0s - loss: 22.7831 - mean_absolute_error: 3.6257 - val_loss: 27.3758 - val_mean_absolute_error: 3.4015 - 90ms/epoch - 3ms/step
# Epoch 22/500
# 26/26 - 0s - loss: 27.0940 - mean_absolute_error: 3.8845 - val_loss: 27.9471 - val_mean_absolute_error: 3.7688 - 89ms/epoch - 3ms/step
# Epoch 23/500
# 26/26 - 0s - loss: 26.9469 - mean_absolute_error: 3.8298 - val_loss: 33.9458 - val_mean_absolute_error: 4.3468 - 90ms/epoch - 3ms/step
# Epoch 24/500
# 26/26 - 0s - loss: 22.8947 - mean_absolute_error: 3.6179 - val_loss: 27.3451 - val_mean_absolute_error: 3.4394 - 91ms/epoch - 4ms/step
# Epoch 25/500
# 26/26 - 0s - loss: 25.8052 - mean_absolute_error: 3.7802 - val_loss: 24.0385 - val_mean_absolute_error: 3.3384 - 104ms/epoch - 4ms/step
# Epoch 26/500
# 26/26 - 0s - loss: 25.8154 - mean_absolute_error: 3.9102 - val_loss: 28.0249 - val_mean_absolute_error: 3.7419 - 99ms/epoch - 4ms/step
# Epoch 27/500
# 26/26 - 0s - loss: 24.8324 - mean_absolute_error: 3.6487 - val_loss: 26.7272 - val_mean_absolute_error: 3.4986 - 97ms/epoch - 4ms/step
# Epoch 28/500
# 26/26 - 0s - loss: 24.8657 - mean_absolute_error: 3.6592 - val_loss: 25.9486 - val_mean_absolute_error: 3.3530 - 89ms/epoch - 3ms/step
# Epoch 29/500
# 26/26 - 0s - loss: 21.1842 - mean_absolute_error: 3.5004 - val_loss: 24.4220 - val_mean_absolute_error: 3.3748 - 105ms/epoch - 4ms/step
# Epoch 30/500
# 26/26 - 0s - loss: 23.2021 - mean_absolute_error: 3.5316 - val_loss: 24.4600 - val_mean_absolute_error: 3.4474 - 94ms/epoch - 4ms/step
# Epoch 31/500
# 26/26 - 0s - loss: 24.9644 - mean_absolute_error: 3.6733 - val_loss: 25.2171 - val_mean_absolute_error: 3.4366 - 90ms/epoch - 3ms/step
# Epoch 32/500
# 26/26 - 0s - loss: 24.9460 - mean_absolute_error: 3.7278 - val_loss: 24.1489 - val_mean_absolute_error: 3.4047 - 90ms/epoch - 3ms/step
# Epoch 33/500
# 26/26 - 0s - loss: 22.7615 - mean_absolute_error: 3.6143 - val_loss: 26.4090 - val_mean_absolute_error: 3.7498 - 86ms/epoch - 3ms/step
# Epoch 34/500
# 26/26 - 0s - loss: 21.9380 - mean_absolute_error: 3.4812 - val_loss: 26.6878 - val_mean_absolute_error: 3.5501 - 89ms/epoch - 3ms/step
# Epoch 35/500
# 26/26 - 0s - loss: 24.4335 - mean_absolute_error: 3.7330 - val_loss: 28.2778 - val_mean_absolute_error: 3.8375 - 87ms/epoch - 3ms/step
# Epoch 36/500
# 26/26 - 0s - loss: 22.7220 - mean_absolute_error: 3.5738 - val_loss: 24.6911 - val_mean_absolute_error: 3.3134 - 88ms/epoch - 3ms/step
# Epoch 37/500
# 26/26 - 0s - loss: 22.3190 - mean_absolute_error: 3.5198 - val_loss: 24.7801 - val_mean_absolute_error: 3.4686 - 88ms/epoch - 3ms/step
# Epoch 38/500
# 26/26 - 0s - loss: 22.3018 - mean_absolute_error: 3.6555 - val_loss: 25.3183 - val_mean_absolute_error: 3.6528 - 84ms/epoch - 3ms/step
# Epoch 39/500
# 26/26 - 0s - loss: 20.8799 - mean_absolute_error: 3.4066 - val_loss: 21.8814 - val_mean_absolute_error: 2.9372 - 94ms/epoch - 4ms/step
# Epoch 40/500
# 26/26 - 0s - loss: 25.3857 - mean_absolute_error: 3.6757 - val_loss: 20.5903 - val_mean_absolute_error: 3.0825 - 89ms/epoch - 3ms/step
# Epoch 41/500
# 26/26 - 0s - loss: 19.4151 - mean_absolute_error: 3.3176 - val_loss: 16.7412 - val_mean_absolute_error: 2.6973 - 97ms/epoch - 4ms/step
# Epoch 42/500
# 26/26 - 0s - loss: 23.2449 - mean_absolute_error: 3.5402 - val_loss: 20.3972 - val_mean_absolute_error: 3.0110 - 94ms/epoch - 4ms/step
# Epoch 43/500
# 26/26 - 0s - loss: 19.6294 - mean_absolute_error: 3.3593 - val_loss: 18.6565 - val_mean_absolute_error: 2.8454 - 85ms/epoch - 3ms/step
# Epoch 44/500
# 26/26 - 0s - loss: 22.4355 - mean_absolute_error: 3.5830 - val_loss: 24.6288 - val_mean_absolute_error: 3.4707 - 98ms/epoch - 4ms/step
# Epoch 45/500
# 26/26 - 0s - loss: 22.3532 - mean_absolute_error: 3.6273 - val_loss: 22.7145 - val_mean_absolute_error: 3.2435 - 88ms/epoch - 3ms/step
# Epoch 46/500
# 26/26 - 0s - loss: 21.9061 - mean_absolute_error: 3.4938 - val_loss: 22.2046 - val_mean_absolute_error: 3.1885 - 87ms/epoch - 3ms/step
# Epoch 47/500
# 26/26 - 0s - loss: 19.0794 - mean_absolute_error: 3.2317 - val_loss: 18.3652 - val_mean_absolute_error: 2.7634 - 85ms/epoch - 3ms/step
# Epoch 48/500
# 26/26 - 0s - loss: 20.8178 - mean_absolute_error: 3.3367 - val_loss: 21.3831 - val_mean_absolute_error: 3.0506 - 88ms/epoch - 3ms/step
# Epoch 49/500
# 26/26 - 0s - loss: 21.8385 - mean_absolute_error: 3.4796 - val_loss: 22.2113 - val_mean_absolute_error: 3.3646 - 87ms/epoch - 3ms/step
# Epoch 50/500
# 26/26 - 0s - loss: 19.8705 - mean_absolute_error: 3.4683 - val_loss: 30.2806 - val_mean_absolute_error: 4.2166 - 91ms/epoch - 4ms/step
# Epoch 51/500
# 26/26 - 0s - loss: 19.5584 - mean_absolute_error: 3.4252 - val_loss: 18.0104 - val_mean_absolute_error: 2.8556 - 87ms/epoch - 3ms/step
# Epoch 52/500
# 26/26 - 0s - loss: 18.8787 - mean_absolute_error: 3.1863 - val_loss: 17.1005 - val_mean_absolute_error: 2.6194 - 107ms/epoch - 4ms/step
# Epoch 53/500
# 26/26 - 0s - loss: 20.4788 - mean_absolute_error: 3.3756 - val_loss: 21.0727 - val_mean_absolute_error: 2.9726 - 99ms/epoch - 4ms/step
# Epoch 54/500
# 26/26 - 0s - loss: 21.3836 - mean_absolute_error: 3.4128 - val_loss: 19.4937 - val_mean_absolute_error: 2.8694 - 85ms/epoch - 3ms/step
# Epoch 55/500
# 26/26 - 0s - loss: 21.3221 - mean_absolute_error: 3.4822 - val_loss: 21.9172 - val_mean_absolute_error: 2.9154 - 87ms/epoch - 3ms/step
# Epoch 56/500
# 26/26 - 0s - loss: 21.7852 - mean_absolute_error: 3.4335 - val_loss: 23.3341 - val_mean_absolute_error: 3.2810 - 87ms/epoch - 3ms/step
# Epoch 57/500
# 26/26 - 0s - loss: 20.1426 - mean_absolute_error: 3.4588 - val_loss: 25.0705 - val_mean_absolute_error: 3.3751 - 98ms/epoch - 4ms/step
# Epoch 58/500
# 26/26 - 0s - loss: 19.2896 - mean_absolute_error: 3.2780 - val_loss: 18.2356 - val_mean_absolute_error: 2.8125 - 94ms/epoch - 4ms/step
# Epoch 59/500
# 26/26 - 0s - loss: 18.0993 - mean_absolute_error: 3.1973 - val_loss: 21.0592 - val_mean_absolute_error: 2.8237 - 98ms/epoch - 4ms/step
# Epoch 60/500
# 26/26 - 0s - loss: 19.1030 - mean_absolute_error: 3.1399 - val_loss: 18.6309 - val_mean_absolute_error: 2.7398 - 94ms/epoch - 4ms/step
# Epoch 61/500
# 26/26 - 0s - loss: 19.9137 - mean_absolute_error: 3.3253 - val_loss: 19.3786 - val_mean_absolute_error: 2.9607 - 88ms/epoch - 3ms/step
# Epoch 62/500
# 26/26 - 0s - loss: 17.4107 - mean_absolute_error: 3.1673 - val_loss: 23.4934 - val_mean_absolute_error: 3.5137 - 107ms/epoch - 4ms/step
# Epoch 63/500
# 26/26 - 0s - loss: 17.4862 - mean_absolute_error: 3.1644 - val_loss: 17.2616 - val_mean_absolute_error: 2.7466 - 97ms/epoch - 4ms/step
# Epoch 64/500
# 26/26 - 0s - loss: 17.3187 - mean_absolute_error: 3.0034 - val_loss: 21.2019 - val_mean_absolute_error: 3.2035 - 90ms/epoch - 3ms/step
# Epoch 65/500
# 26/26 - 0s - loss: 17.9069 - mean_absolute_error: 3.2112 - val_loss: 19.4136 - val_mean_absolute_error: 2.9594 - 96ms/epoch - 4ms/step
# Epoch 66/500
# 26/26 - 0s - loss: 19.7693 - mean_absolute_error: 3.3918 - val_loss: 23.4981 - val_mean_absolute_error: 3.0478 - 91ms/epoch - 3ms/step
# Epoch 67/500
# 26/26 - 0s - loss: 19.5490 - mean_absolute_error: 3.2584 - val_loss: 19.9207 - val_mean_absolute_error: 2.9607 - 89ms/epoch - 3ms/step
# Epoch 68/500
# 26/26 - 0s - loss: 17.4125 - mean_absolute_error: 3.1072 - val_loss: 19.2666 - val_mean_absolute_error: 2.8492 - 90ms/epoch - 3ms/step
# Epoch 69/500
# 26/26 - 0s - loss: 20.0012 - mean_absolute_error: 3.2533 - val_loss: 21.4553 - val_mean_absolute_error: 3.1819 - 88ms/epoch - 3ms/step
# Epoch 70/500
# 26/26 - 0s - loss: 17.2112 - mean_absolute_error: 3.1471 - val_loss: 19.4871 - val_mean_absolute_error: 3.0632 - 88ms/epoch - 3ms/step
# Epoch 71/500
# 26/26 - 0s - loss: 15.3836 - mean_absolute_error: 2.9202 - val_loss: 21.6864 - val_mean_absolute_error: 3.3392 - 91ms/epoch - 3ms/step
# Epoch 72/500
# 26/26 - 0s - loss: 16.7143 - mean_absolute_error: 3.1119 - val_loss: 19.4203 - val_mean_absolute_error: 3.0281 - 112ms/epoch - 4ms/step
# Epoch 73/500
# 26/26 - 0s - loss: 15.9034 - mean_absolute_error: 3.0348 - val_loss: 18.9914 - val_mean_absolute_error: 2.8324 - 94ms/epoch - 4ms/step
# Epoch 74/500
# 26/26 - 0s - loss: 16.9890 - mean_absolute_error: 3.0956 - val_loss: 17.3329 - val_mean_absolute_error: 2.6416 - 84ms/epoch - 3ms/step
# Epoch 75/500
# 26/26 - 0s - loss: 19.6957 - mean_absolute_error: 3.3345 - val_loss: 19.3822 - val_mean_absolute_error: 2.8117 - 85ms/epoch - 3ms/step
# Epoch 76/500
# 26/26 - 0s - loss: 17.0461 - mean_absolute_error: 3.1079 - val_loss: 18.1503 - val_mean_absolute_error: 2.7760 - 86ms/epoch - 3ms/step
# Epoch 77/500
# 26/26 - 0s - loss: 19.7967 - mean_absolute_error: 3.2213 - val_loss: 21.5142 - val_mean_absolute_error: 2.9536 - 96ms/epoch - 4ms/step
# Epoch 78/500
# 26/26 - 0s - loss: 18.4746 - mean_absolute_error: 3.1972 - val_loss: 24.3048 - val_mean_absolute_error: 3.5649 - 86ms/epoch - 3ms/step
# Epoch 79/500
# 26/26 - 0s - loss: 18.1543 - mean_absolute_error: 3.2293 - val_loss: 18.8681 - val_mean_absolute_error: 2.7934 - 87ms/epoch - 3ms/step
# Epoch 80/500
# 26/26 - 0s - loss: 20.2772 - mean_absolute_error: 3.3863 - val_loss: 19.1058 - val_mean_absolute_error: 2.9074 - 98ms/epoch - 4ms/step
# Epoch 81/500
# 26/26 - 0s - loss: 17.3081 - mean_absolute_error: 3.1526 - val_loss: 21.1699 - val_mean_absolute_error: 3.0148 - 101ms/epoch - 4ms/step
# Epoch 82/500
# 26/26 - 0s - loss: 14.8635 - mean_absolute_error: 3.0008 - val_loss: 17.7556 - val_mean_absolute_error: 2.7002 - 97ms/epoch - 4ms/step
# Epoch 83/500
# 26/26 - 0s - loss: 18.0527 - mean_absolute_error: 3.1729 - val_loss: 20.9871 - val_mean_absolute_error: 2.8162 - 97ms/epoch - 4ms/step
# Epoch 84/500
# 26/26 - 0s - loss: 15.5727 - mean_absolute_error: 2.9640 - val_loss: 20.2268 - val_mean_absolute_error: 3.2543 - 93ms/epoch - 4ms/step
# Epoch 85/500
# 26/26 - 0s - loss: 15.0098 - mean_absolute_error: 2.9601 - val_loss: 20.3588 - val_mean_absolute_error: 3.2851 - 88ms/epoch - 3ms/step
# Epoch 86/500
# 26/26 - 0s - loss: 20.4789 - mean_absolute_error: 3.2991 - val_loss: 22.7301 - val_mean_absolute_error: 3.5007 - 88ms/epoch - 3ms/step
# Epoch 87/500
# 26/26 - 0s - loss: 15.0984 - mean_absolute_error: 2.9348 - val_loss: 20.3048 - val_mean_absolute_error: 3.0756 - 88ms/epoch - 3ms/step
# Epoch 88/500
# 26/26 - 0s - loss: 16.0603 - mean_absolute_error: 3.0637 - val_loss: 19.7833 - val_mean_absolute_error: 3.2016 - 94ms/epoch - 4ms/step
# Epoch 89/500
# 26/26 - 0s - loss: 19.5414 - mean_absolute_error: 3.2320 - val_loss: 19.0451 - val_mean_absolute_error: 2.9429 - 87ms/epoch - 3ms/step
# Epoch 90/500
# 26/26 - 0s - loss: 14.7008 - mean_absolute_error: 2.8563 - val_loss: 17.8072 - val_mean_absolute_error: 2.6183 - 96ms/epoch - 4ms/step
# Epoch 91/500
# 26/26 - 0s - loss: 15.4443 - mean_absolute_error: 3.0679 - val_loss: 18.7652 - val_mean_absolute_error: 3.0783 - 85ms/epoch - 3ms/step
# Epoch 92/500
# 26/26 - 0s - loss: 15.6260 - mean_absolute_error: 2.9796 - val_loss: 17.3309 - val_mean_absolute_error: 2.6173 - 87ms/epoch - 3ms/step
# Epoch 93/500
# 26/26 - 0s - loss: 18.3202 - mean_absolute_error: 3.1050 - val_loss: 19.8003 - val_mean_absolute_error: 3.1949 - 94ms/epoch - 4ms/step
# Epoch 94/500
# 26/26 - 0s - loss: 17.3325 - mean_absolute_error: 3.0734 - val_loss: 17.4857 - val_mean_absolute_error: 2.8600 - 92ms/epoch - 4ms/step
# Epoch 95/500
# 26/26 - 0s - loss: 13.2831 - mean_absolute_error: 2.7809 - val_loss: 17.7400 - val_mean_absolute_error: 2.6550 - 87ms/epoch - 3ms/step
# Epoch 96/500
# 26/26 - 0s - loss: 15.1968 - mean_absolute_error: 2.9628 - val_loss: 17.9109 - val_mean_absolute_error: 2.7312 - 95ms/epoch - 4ms/step
# Epoch 97/500
# 26/26 - 0s - loss: 17.2371 - mean_absolute_error: 3.0399 - val_loss: 17.8193 - val_mean_absolute_error: 2.7931 - 88ms/epoch - 3ms/step
# Epoch 98/500
# 26/26 - 0s - loss: 16.0973 - mean_absolute_error: 2.9415 - val_loss: 19.2650 - val_mean_absolute_error: 3.0014 - 86ms/epoch - 3ms/step
# Epoch 99/500
# 26/26 - 0s - loss: 18.1320 - mean_absolute_error: 3.1395 - val_loss: 13.3470 - val_mean_absolute_error: 2.4205 - 91ms/epoch - 4ms/step
# Epoch 100/500
# 26/26 - 0s - loss: 15.7085 - mean_absolute_error: 2.9832 - val_loss: 14.4396 - val_mean_absolute_error: 2.4574 - 85ms/epoch - 3ms/step
# Epoch 101/500
# 26/26 - 0s - loss: 16.6544 - mean_absolute_error: 3.1217 - val_loss: 16.3112 - val_mean_absolute_error: 2.5387 - 86ms/epoch - 3ms/step
# Epoch 102/500
# 26/26 - 0s - loss: 19.1333 - mean_absolute_error: 3.2840 - val_loss: 18.7915 - val_mean_absolute_error: 3.0999 - 89ms/epoch - 3ms/step
# Epoch 103/500
# 26/26 - 0s - loss: 16.1551 - mean_absolute_error: 3.0314 - val_loss: 16.7733 - val_mean_absolute_error: 2.8717 - 92ms/epoch - 4ms/step
# Epoch 104/500
# 26/26 - 0s - loss: 15.9323 - mean_absolute_error: 3.1011 - val_loss: 17.7133 - val_mean_absolute_error: 2.9236 - 106ms/epoch - 4ms/step
# Epoch 105/500
# 26/26 - 0s - loss: 15.2448 - mean_absolute_error: 2.9569 - val_loss: 16.2803 - val_mean_absolute_error: 2.7484 - 92ms/epoch - 4ms/step
# Epoch 106/500
# 26/26 - 0s - loss: 14.2939 - mean_absolute_error: 2.7539 - val_loss: 16.6339 - val_mean_absolute_error: 2.8203 - 87ms/epoch - 3ms/step
# Epoch 107/500
# 26/26 - 0s - loss: 15.4493 - mean_absolute_error: 2.8667 - val_loss: 16.7251 - val_mean_absolute_error: 2.8148 - 88ms/epoch - 3ms/step
# Epoch 108/500
# 26/26 - 0s - loss: 14.8588 - mean_absolute_error: 2.9563 - val_loss: 23.0526 - val_mean_absolute_error: 3.4060 - 97ms/epoch - 4ms/step
# Epoch 109/500
# 26/26 - 0s - loss: 16.7080 - mean_absolute_error: 3.0155 - val_loss: 15.6257 - val_mean_absolute_error: 2.5814 - 96ms/epoch - 4ms/step
# Epoch 110/500
# 26/26 - 0s - loss: 13.7336 - mean_absolute_error: 2.8862 - val_loss: 15.7823 - val_mean_absolute_error: 2.5358 - 94ms/epoch - 4ms/step
# Epoch 111/500
# 26/26 - 0s - loss: 15.4789 - mean_absolute_error: 2.9059 - val_loss: 20.5393 - val_mean_absolute_error: 3.2827 - 89ms/epoch - 3ms/step
# Epoch 112/500
# 26/26 - 0s - loss: 18.5545 - mean_absolute_error: 3.1890 - val_loss: 21.6947 - val_mean_absolute_error: 3.3411 - 90ms/epoch - 3ms/step
# Epoch 113/500
# 26/26 - 0s - loss: 16.6839 - mean_absolute_error: 3.0211 - val_loss: 20.0921 - val_mean_absolute_error: 3.2118 - 88ms/epoch - 3ms/step
# Epoch 114/500
# 26/26 - 0s - loss: 14.9173 - mean_absolute_error: 2.7721 - val_loss: 20.1876 - val_mean_absolute_error: 3.4058 - 87ms/epoch - 3ms/step
# Epoch 115/500
# 26/26 - 0s - loss: 14.6877 - mean_absolute_error: 2.9017 - val_loss: 16.5958 - val_mean_absolute_error: 2.9413 - 108ms/epoch - 4ms/step
# Epoch 116/500
# 26/26 - 0s - loss: 16.4433 - mean_absolute_error: 2.9424 - val_loss: 19.3669 - val_mean_absolute_error: 3.1554 - 86ms/epoch - 3ms/step
# Epoch 117/500
# 26/26 - 0s - loss: 17.0735 - mean_absolute_error: 3.0987 - val_loss: 15.8977 - val_mean_absolute_error: 2.6642 - 95ms/epoch - 4ms/step
# Epoch 118/500
# 26/26 - 0s - loss: 15.4192 - mean_absolute_error: 2.8713 - val_loss: 15.4801 - val_mean_absolute_error: 2.4299 - 101ms/epoch - 4ms/step
# Epoch 119/500
# 26/26 - 0s - loss: 17.6374 - mean_absolute_error: 3.0626 - val_loss: 18.4989 - val_mean_absolute_error: 2.9835 - 97ms/epoch - 4ms/step
# Epoch 120/500
# 26/26 - 0s - loss: 16.0793 - mean_absolute_error: 2.9723 - val_loss: 17.2363 - val_mean_absolute_error: 2.7540 - 87ms/epoch - 3ms/step
# Epoch 121/500
# 26/26 - 0s - loss: 16.7622 - mean_absolute_error: 3.0169 - val_loss: 18.2626 - val_mean_absolute_error: 2.9593 - 99ms/epoch - 4ms/step
# Epoch 122/500
# 26/26 - 0s - loss: 15.9307 - mean_absolute_error: 2.9816 - val_loss: 13.4800 - val_mean_absolute_error: 2.2881 - 98ms/epoch - 4ms/step
# Epoch 123/500
# 26/26 - 0s - loss: 16.2353 - mean_absolute_error: 2.9981 - val_loss: 14.4181 - val_mean_absolute_error: 2.3668 - 87ms/epoch - 3ms/step
# Epoch 124/500
# 26/26 - 0s - loss: 14.6526 - mean_absolute_error: 2.8766 - val_loss: 14.9339 - val_mean_absolute_error: 2.3329 - 88ms/epoch - 3ms/step
# Epoch 125/500
# 26/26 - 0s - loss: 15.3611 - mean_absolute_error: 2.9049 - val_loss: 13.8380 - val_mean_absolute_error: 2.3913 - 106ms/epoch - 4ms/step
# Epoch 126/500
# 26/26 - 0s - loss: 15.5053 - mean_absolute_error: 2.9209 - val_loss: 16.0646 - val_mean_absolute_error: 2.8879 - 90ms/epoch - 3ms/step
# Epoch 127/500
# 26/26 - 0s - loss: 13.9801 - mean_absolute_error: 2.8500 - val_loss: 14.1222 - val_mean_absolute_error: 2.5393 - 88ms/epoch - 3ms/step
# Epoch 128/500
# 26/26 - 0s - loss: 14.0989 - mean_absolute_error: 2.8083 - val_loss: 14.2941 - val_mean_absolute_error: 2.5120 - 86ms/epoch - 3ms/step
# Epoch 129/500
# 26/26 - 0s - loss: 13.8643 - mean_absolute_error: 2.7315 - val_loss: 13.8452 - val_mean_absolute_error: 2.4040 - 84ms/epoch - 3ms/step
# Epoch 130/500
# 26/26 - 0s - loss: 15.2043 - mean_absolute_error: 2.9068 - val_loss: 14.6972 - val_mean_absolute_error: 2.5063 - 86ms/epoch - 3ms/step
# Epoch 131/500
# 26/26 - 0s - loss: 14.9752 - mean_absolute_error: 2.8859 - val_loss: 13.9158 - val_mean_absolute_error: 2.4445 - 87ms/epoch - 3ms/step
# Epoch 132/500
# 26/26 - 0s - loss: 13.6381 - mean_absolute_error: 2.7852 - val_loss: 16.6937 - val_mean_absolute_error: 2.6550 - 91ms/epoch - 4ms/step
# Epoch 133/500
# 26/26 - 0s - loss: 14.9238 - mean_absolute_error: 2.8295 - val_loss: 15.2053 - val_mean_absolute_error: 2.5233 - 95ms/epoch - 4ms/step
# Epoch 134/500
# 26/26 - 0s - loss: 16.0003 - mean_absolute_error: 2.8703 - val_loss: 15.2631 - val_mean_absolute_error: 2.4474 - 91ms/epoch - 4ms/step
# Epoch 135/500
# 26/26 - 0s - loss: 17.3061 - mean_absolute_error: 2.9974 - val_loss: 14.7212 - val_mean_absolute_error: 2.4761 - 94ms/epoch - 4ms/step
# Epoch 136/500
# 26/26 - 0s - loss: 14.8604 - mean_absolute_error: 2.8687 - val_loss: 13.4115 - val_mean_absolute_error: 2.3311 - 92ms/epoch - 4ms/step
# Epoch 137/500
# 26/26 - 0s - loss: 14.7901 - mean_absolute_error: 2.8710 - val_loss: 17.6827 - val_mean_absolute_error: 3.0751 - 94ms/epoch - 4ms/step
# Epoch 138/500
# 26/26 - 0s - loss: 14.5399 - mean_absolute_error: 2.8722 - val_loss: 17.2392 - val_mean_absolute_error: 3.0000 - 86ms/epoch - 3ms/step
# Epoch 139/500
# 26/26 - 0s - loss: 17.2442 - mean_absolute_error: 3.0021 - val_loss: 14.3570 - val_mean_absolute_error: 2.5200 - 97ms/epoch - 4ms/step
# Epoch 140/500
# 26/26 - 0s - loss: 16.5641 - mean_absolute_error: 2.9677 - val_loss: 16.0314 - val_mean_absolute_error: 2.6120 - 95ms/epoch - 4ms/step
# Epoch 141/500
# 26/26 - 0s - loss: 13.2988 - mean_absolute_error: 2.7568 - val_loss: 13.6462 - val_mean_absolute_error: 2.3237 - 87ms/epoch - 3ms/step
# Epoch 142/500
# 26/26 - 0s - loss: 13.2941 - mean_absolute_error: 2.7598 - val_loss: 14.0869 - val_mean_absolute_error: 2.3774 - 98ms/epoch - 4ms/step
# Epoch 143/500
# 26/26 - 0s - loss: 14.7417 - mean_absolute_error: 2.8532 - val_loss: 16.1087 - val_mean_absolute_error: 2.6855 - 89ms/epoch - 3ms/step
# Epoch 144/500
# 26/26 - 0s - loss: 16.3539 - mean_absolute_error: 3.0064 - val_loss: 13.9029 - val_mean_absolute_error: 2.3750 - 91ms/epoch - 3ms/step
# Epoch 145/500
# 26/26 - 0s - loss: 14.9237 - mean_absolute_error: 2.8935 - val_loss: 13.5980 - val_mean_absolute_error: 2.4726 - 106ms/epoch - 4ms/step
# Epoch 146/500
# 26/26 - 0s - loss: 13.1156 - mean_absolute_error: 2.7656 - val_loss: 14.0023 - val_mean_absolute_error: 2.4314 - 91ms/epoch - 4ms/step
# Epoch 147/500
# 26/26 - 0s - loss: 13.9708 - mean_absolute_error: 2.7553 - val_loss: 12.9793 - val_mean_absolute_error: 2.3205 - 98ms/epoch - 4ms/step
# Epoch 148/500
# 26/26 - 0s - loss: 13.4177 - mean_absolute_error: 2.8133 - val_loss: 15.6837 - val_mean_absolute_error: 2.7966 - 88ms/epoch - 3ms/step
# Epoch 149/500
# 26/26 - 0s - loss: 15.1728 - mean_absolute_error: 2.9067 - val_loss: 17.0651 - val_mean_absolute_error: 3.0591 - 87ms/epoch - 3ms/step
# Epoch 150/500
# 26/26 - 0s - loss: 15.6020 - mean_absolute_error: 2.8344 - val_loss: 19.4484 - val_mean_absolute_error: 3.1572 - 89ms/epoch - 3ms/step
# Epoch 151/500
# 26/26 - 0s - loss: 16.6458 - mean_absolute_error: 2.9733 - val_loss: 16.5581 - val_mean_absolute_error: 2.6968 - 98ms/epoch - 4ms/step
# Epoch 152/500
# 26/26 - 0s - loss: 12.7192 - mean_absolute_error: 2.6708 - val_loss: 16.7682 - val_mean_absolute_error: 2.7100 - 95ms/epoch - 4ms/step
# Epoch 153/500
# 26/26 - 0s - loss: 14.8658 - mean_absolute_error: 2.8583 - val_loss: 16.6118 - val_mean_absolute_error: 2.8285 - 90ms/epoch - 3ms/step
# Epoch 154/500
# 26/26 - 0s - loss: 13.1484 - mean_absolute_error: 2.6985 - val_loss: 14.4808 - val_mean_absolute_error: 2.6162 - 86ms/epoch - 3ms/step
# Epoch 155/500
# 26/26 - 0s - loss: 11.7226 - mean_absolute_error: 2.6291 - val_loss: 14.0263 - val_mean_absolute_error: 2.5141 - 91ms/epoch - 3ms/step
# Epoch 156/500
# 26/26 - 0s - loss: 13.2438 - mean_absolute_error: 2.8194 - val_loss: 12.8080 - val_mean_absolute_error: 2.2537 - 93ms/epoch - 4ms/step
# Epoch 157/500
# 26/26 - 0s - loss: 13.9652 - mean_absolute_error: 2.8134 - val_loss: 13.7405 - val_mean_absolute_error: 2.3566 - 94ms/epoch - 4ms/step
# Epoch 158/500
# 26/26 - 0s - loss: 13.5815 - mean_absolute_error: 2.7083 - val_loss: 12.8581 - val_mean_absolute_error: 2.3401 - 86ms/epoch - 3ms/step
# Epoch 159/500
# 26/26 - 0s - loss: 12.2628 - mean_absolute_error: 2.6139 - val_loss: 13.5191 - val_mean_absolute_error: 2.5751 - 87ms/epoch - 3ms/step
# Epoch 160/500
# 26/26 - 0s - loss: 13.5982 - mean_absolute_error: 2.7740 - val_loss: 14.3800 - val_mean_absolute_error: 2.6335 - 99ms/epoch - 4ms/step
# Epoch 161/500
# 26/26 - 0s - loss: 15.3254 - mean_absolute_error: 2.9007 - val_loss: 15.7380 - val_mean_absolute_error: 2.8362 - 90ms/epoch - 3ms/step
# Epoch 162/500
# 26/26 - 0s - loss: 13.8519 - mean_absolute_error: 2.8045 - val_loss: 17.0409 - val_mean_absolute_error: 2.9083 - 99ms/epoch - 4ms/step
# Epoch 163/500
# 26/26 - 0s - loss: 13.6217 - mean_absolute_error: 2.7211 - val_loss: 14.6834 - val_mean_absolute_error: 2.6552 - 86ms/epoch - 3ms/step
# Epoch 164/500
# 26/26 - 0s - loss: 12.3509 - mean_absolute_error: 2.6380 - val_loss: 14.4600 - val_mean_absolute_error: 2.4752 - 86ms/epoch - 3ms/step
# Epoch 165/500
# 26/26 - 0s - loss: 15.2407 - mean_absolute_error: 2.8358 - val_loss: 20.7309 - val_mean_absolute_error: 3.0391 - 102ms/epoch - 4ms/step
# Epoch 166/500
# 26/26 - 0s - loss: 15.8017 - mean_absolute_error: 2.8665 - val_loss: 14.2402 - val_mean_absolute_error: 2.4660 - 87ms/epoch - 3ms/step
# Epoch 167/500
# 26/26 - 0s - loss: 12.9658 - mean_absolute_error: 2.6588 - val_loss: 14.3317 - val_mean_absolute_error: 2.3982 - 105ms/epoch - 4ms/step
# Epoch 168/500
# 26/26 - 0s - loss: 12.7018 - mean_absolute_error: 2.6932 - val_loss: 12.4688 - val_mean_absolute_error: 2.2373 - 97ms/epoch - 4ms/step
# Epoch 169/500
# 26/26 - 0s - loss: 12.2528 - mean_absolute_error: 2.6305 - val_loss: 14.8045 - val_mean_absolute_error: 2.6643 - 96ms/epoch - 4ms/step
# Epoch 170/500
# 26/26 - 0s - loss: 13.8076 - mean_absolute_error: 2.6414 - val_loss: 15.1158 - val_mean_absolute_error: 2.7412 - 98ms/epoch - 4ms/step
# Epoch 171/500
# 26/26 - 0s - loss: 11.6167 - mean_absolute_error: 2.6252 - val_loss: 13.6235 - val_mean_absolute_error: 2.4618 - 96ms/epoch - 4ms/step
# Epoch 172/500
# 26/26 - 0s - loss: 11.9488 - mean_absolute_error: 2.6029 - val_loss: 18.2192 - val_mean_absolute_error: 3.1028 - 89ms/epoch - 3ms/step
# Epoch 173/500
# 26/26 - 0s - loss: 11.4570 - mean_absolute_error: 2.5172 - val_loss: 15.7057 - val_mean_absolute_error: 2.7777 - 90ms/epoch - 3ms/step
# Epoch 174/500
# 26/26 - 0s - loss: 12.3383 - mean_absolute_error: 2.5686 - val_loss: 17.4345 - val_mean_absolute_error: 2.9602 - 87ms/epoch - 3ms/step
# Epoch 175/500
# 26/26 - 0s - loss: 13.0258 - mean_absolute_error: 2.5924 - val_loss: 16.0075 - val_mean_absolute_error: 2.7308 - 109ms/epoch - 4ms/step
# Epoch 176/500
# 26/26 - 0s - loss: 12.8024 - mean_absolute_error: 2.6956 - val_loss: 15.7262 - val_mean_absolute_error: 2.8100 - 99ms/epoch - 4ms/step
# Epoch 177/500
# 26/26 - 0s - loss: 12.8138 - mean_absolute_error: 2.6154 - val_loss: 15.9733 - val_mean_absolute_error: 2.8411 - 86ms/epoch - 3ms/step
# Epoch 178/500
# 26/26 - 0s - loss: 15.6546 - mean_absolute_error: 2.8162 - val_loss: 16.1100 - val_mean_absolute_error: 2.8914 - 88ms/epoch - 3ms/step
# Epoch 179/500
# 26/26 - 0s - loss: 13.8178 - mean_absolute_error: 2.7744 - val_loss: 14.1453 - val_mean_absolute_error: 2.4922 - 89ms/epoch - 3ms/step
# Epoch 180/500
# 26/26 - 0s - loss: 11.2529 - mean_absolute_error: 2.4471 - val_loss: 13.9959 - val_mean_absolute_error: 2.3668 - 90ms/epoch - 3ms/step
# Epoch 181/500
# 26/26 - 0s - loss: 11.7367 - mean_absolute_error: 2.6270 - val_loss: 13.8179 - val_mean_absolute_error: 2.4438 - 96ms/epoch - 4ms/step
# Epoch 182/500
# 26/26 - 0s - loss: 12.1805 - mean_absolute_error: 2.6104 - val_loss: 14.7422 - val_mean_absolute_error: 2.6773 - 86ms/epoch - 3ms/step
# Epoch 183/500
# 26/26 - 0s - loss: 12.2996 - mean_absolute_error: 2.7442 - val_loss: 13.7521 - val_mean_absolute_error: 2.3523 - 102ms/epoch - 4ms/step
# Epoch 184/500
# 26/26 - 0s - loss: 13.8405 - mean_absolute_error: 2.7355 - val_loss: 15.9884 - val_mean_absolute_error: 2.8674 - 86ms/epoch - 3ms/step
# Epoch 185/500
# 26/26 - 0s - loss: 14.7854 - mean_absolute_error: 2.7284 - val_loss: 14.1590 - val_mean_absolute_error: 2.5883 - 98ms/epoch - 4ms/step
# Epoch 186/500
# 26/26 - 0s - loss: 13.1693 - mean_absolute_error: 2.7422 - val_loss: 16.3517 - val_mean_absolute_error: 2.8963 - 87ms/epoch - 3ms/step
# Epoch 187/500
# 26/26 - 0s - loss: 12.8212 - mean_absolute_error: 2.7769 - val_loss: 19.1380 - val_mean_absolute_error: 3.3218 - 105ms/epoch - 4ms/step
# Epoch 188/500
# 26/26 - 0s - loss: 13.3955 - mean_absolute_error: 2.7180 - val_loss: 18.1691 - val_mean_absolute_error: 3.1782 - 95ms/epoch - 4ms/step
# Epoch 189/500
# 26/26 - 0s - loss: 13.2177 - mean_absolute_error: 2.7476 - val_loss: 14.6345 - val_mean_absolute_error: 2.5924 - 88ms/epoch - 3ms/step
# Epoch 190/500
# 26/26 - 0s - loss: 11.2867 - mean_absolute_error: 2.4814 - val_loss: 14.8876 - val_mean_absolute_error: 2.6628 - 96ms/epoch - 4ms/step
# Epoch 191/500
# 26/26 - 0s - loss: 12.7177 - mean_absolute_error: 2.6027 - val_loss: 16.6605 - val_mean_absolute_error: 2.9530 - 100ms/epoch - 4ms/step
# Epoch 192/500
# 26/26 - 0s - loss: 13.6199 - mean_absolute_error: 2.7396 - val_loss: 15.1996 - val_mean_absolute_error: 2.7738 - 96ms/epoch - 4ms/step
# Epoch 193/500
# 26/26 - 0s - loss: 11.9527 - mean_absolute_error: 2.5851 - val_loss: 16.6436 - val_mean_absolute_error: 2.9877 - 85ms/epoch - 3ms/step
# Epoch 194/500
# 26/26 - 0s - loss: 14.5469 - mean_absolute_error: 2.7320 - val_loss: 15.2529 - val_mean_absolute_error: 2.7000 - 91ms/epoch - 4ms/step
# Epoch 195/500
# 26/26 - 0s - loss: 13.5562 - mean_absolute_error: 2.6985 - val_loss: 14.5069 - val_mean_absolute_error: 2.5738 - 87ms/epoch - 3ms/step
# Epoch 196/500
# 26/26 - 0s - loss: 12.0678 - mean_absolute_error: 2.5946 - val_loss: 17.4643 - val_mean_absolute_error: 3.0334 - 89ms/epoch - 3ms/step
# Epoch 197/500
# 26/26 - 0s - loss: 12.2969 - mean_absolute_error: 2.6039 - val_loss: 16.6334 - val_mean_absolute_error: 2.9365 - 93ms/epoch - 4ms/step
# Epoch 198/500
# 26/26 - 0s - loss: 10.7078 - mean_absolute_error: 2.4321 - val_loss: 18.2139 - val_mean_absolute_error: 3.1100 - 88ms/epoch - 3ms/step
# Epoch 199/500
# 26/26 - 0s - loss: 12.3465 - mean_absolute_error: 2.6672 - val_loss: 15.9829 - val_mean_absolute_error: 2.8518 - 86ms/epoch - 3ms/step
# Epoch 200/500
# 26/26 - 0s - loss: 13.3981 - mean_absolute_error: 2.6584 - val_loss: 15.9672 - val_mean_absolute_error: 2.8680 - 90ms/epoch - 3ms/step
# Epoch 201/500
# 26/26 - 0s - loss: 11.7470 - mean_absolute_error: 2.7018 - val_loss: 13.3748 - val_mean_absolute_error: 2.4198 - 88ms/epoch - 3ms/step
# Epoch 202/500
# 26/26 - 0s - loss: 13.2477 - mean_absolute_error: 2.6763 - val_loss: 16.9403 - val_mean_absolute_error: 3.1021 - 85ms/epoch - 3ms/step
# Epoch 203/500
# 26/26 - 0s - loss: 13.7542 - mean_absolute_error: 2.7496 - val_loss: 16.5202 - val_mean_absolute_error: 2.9884 - 89ms/epoch - 3ms/step
# Epoch 204/500
# 26/26 - 0s - loss: 14.4541 - mean_absolute_error: 2.7343 - val_loss: 17.0061 - val_mean_absolute_error: 3.0779 - 91ms/epoch - 3ms/step
# Epoch 205/500
# 26/26 - 0s - loss: 11.8998 - mean_absolute_error: 2.6297 - val_loss: 14.0861 - val_mean_absolute_error: 2.6742 - 86ms/epoch - 3ms/step
# Epoch 206/500
# 26/26 - 0s - loss: 12.4300 - mean_absolute_error: 2.6308 - val_loss: 16.6334 - val_mean_absolute_error: 3.0250 - 100ms/epoch - 4ms/step
# Epoch 207/500
# 26/26 - 0s - loss: 12.8885 - mean_absolute_error: 2.6277 - val_loss: 13.7871 - val_mean_absolute_error: 2.4816 - 88ms/epoch - 3ms/step
# Epoch 208/500
# 26/26 - 0s - loss: 13.5657 - mean_absolute_error: 2.7302 - val_loss: 13.4068 - val_mean_absolute_error: 2.4268 - 102ms/epoch - 4ms/step
# Epoch 209/500
# 26/26 - 0s - loss: 13.2949 - mean_absolute_error: 2.5985 - val_loss: 12.8278 - val_mean_absolute_error: 2.4605 - 102ms/epoch - 4ms/step
# Epoch 210/500
# 26/26 - 0s - loss: 12.1943 - mean_absolute_error: 2.4998 - val_loss: 13.0987 - val_mean_absolute_error: 2.4934 - 97ms/epoch - 4ms/step
# Epoch 211/500
# 26/26 - 0s - loss: 10.5600 - mean_absolute_error: 2.4854 - val_loss: 14.5351 - val_mean_absolute_error: 2.7511 - 90ms/epoch - 3ms/step
# Epoch 212/500
# 26/26 - 0s - loss: 10.8788 - mean_absolute_error: 2.4706 - val_loss: 12.4363 - val_mean_absolute_error: 2.3444 - 88ms/epoch - 3ms/step
# Epoch 213/500
# 26/26 - 0s - loss: 11.4287 - mean_absolute_error: 2.4728 - val_loss: 12.6168 - val_mean_absolute_error: 2.3419 - 95ms/epoch - 4ms/step
# Epoch 214/500
# 26/26 - 0s - loss: 12.1594 - mean_absolute_error: 2.5516 - val_loss: 12.5444 - val_mean_absolute_error: 2.3437 - 103ms/epoch - 4ms/step
# Epoch 215/500
# 26/26 - 0s - loss: 13.1288 - mean_absolute_error: 2.6590 - val_loss: 13.6961 - val_mean_absolute_error: 2.4229 - 87ms/epoch - 3ms/step
# Epoch 216/500
# 26/26 - 0s - loss: 12.5052 - mean_absolute_error: 2.5475 - val_loss: 13.8618 - val_mean_absolute_error: 2.3793 - 93ms/epoch - 4ms/step
# Epoch 217/500
# 26/26 - 0s - loss: 12.5572 - mean_absolute_error: 2.6640 - val_loss: 14.5900 - val_mean_absolute_error: 2.6614 - 89ms/epoch - 3ms/step
# Epoch 218/500
# 26/26 - 0s - loss: 11.3511 - mean_absolute_error: 2.5633 - val_loss: 13.0922 - val_mean_absolute_error: 2.4211 - 93ms/epoch - 4ms/step
# Epoch 219/500
# 26/26 - 0s - loss: 13.8127 - mean_absolute_error: 2.7635 - val_loss: 13.6639 - val_mean_absolute_error: 2.5853 - 97ms/epoch - 4ms/step
# Epoch 220/500
# 26/26 - 0s - loss: 13.9508 - mean_absolute_error: 2.7577 - val_loss: 14.3493 - val_mean_absolute_error: 2.6860 - 89ms/epoch - 3ms/step
# Epoch 221/500
# 26/26 - 0s - loss: 11.8194 - mean_absolute_error: 2.6203 - val_loss: 11.8825 - val_mean_absolute_error: 2.1580 - 95ms/epoch - 4ms/step
# Epoch 222/500
# 26/26 - 0s - loss: 13.2889 - mean_absolute_error: 2.6893 - val_loss: 12.0394 - val_mean_absolute_error: 2.3200 - 92ms/epoch - 4ms/step
# Epoch 223/500
# 26/26 - 0s - loss: 14.4557 - mean_absolute_error: 2.7008 - val_loss: 12.6505 - val_mean_absolute_error: 2.4066 - 86ms/epoch - 3ms/step
# Epoch 224/500
# 26/26 - 0s - loss: 14.2019 - mean_absolute_error: 2.7383 - val_loss: 13.3063 - val_mean_absolute_error: 2.2914 - 90ms/epoch - 3ms/step
# Epoch 225/500
# 26/26 - 0s - loss: 15.1257 - mean_absolute_error: 2.8315 - val_loss: 12.8156 - val_mean_absolute_error: 2.3130 - 89ms/epoch - 3ms/step
# Epoch 226/500
# 26/26 - 0s - loss: 12.1642 - mean_absolute_error: 2.5698 - val_loss: 14.2563 - val_mean_absolute_error: 2.5466 - 89ms/epoch - 3ms/step
# Epoch 227/500
# 26/26 - 0s - loss: 13.3426 - mean_absolute_error: 2.7210 - val_loss: 14.6393 - val_mean_absolute_error: 2.6751 - 91ms/epoch - 4ms/step
# Epoch 228/500
# 26/26 - 0s - loss: 12.7300 - mean_absolute_error: 2.6984 - val_loss: 11.7629 - val_mean_absolute_error: 2.3081 - 90ms/epoch - 3ms/step
# Epoch 229/500
# 26/26 - 0s - loss: 15.9866 - mean_absolute_error: 2.9265 - val_loss: 11.6609 - val_mean_absolute_error: 2.1926 - 98ms/epoch - 4ms/step
# Epoch 230/500
# 26/26 - 0s - loss: 11.9995 - mean_absolute_error: 2.4989 - val_loss: 13.9256 - val_mean_absolute_error: 2.3593 - 102ms/epoch - 4ms/step
# Epoch 231/500
# 26/26 - 0s - loss: 12.3916 - mean_absolute_error: 2.7427 - val_loss: 15.0432 - val_mean_absolute_error: 2.5555 - 109ms/epoch - 4ms/step
# Epoch 232/500
# 26/26 - 0s - loss: 11.3746 - mean_absolute_error: 2.5220 - val_loss: 12.7611 - val_mean_absolute_error: 2.2855 - 90ms/epoch - 3ms/step
# Epoch 233/500
# 26/26 - 0s - loss: 10.4248 - mean_absolute_error: 2.4108 - val_loss: 14.1595 - val_mean_absolute_error: 2.6071 - 98ms/epoch - 4ms/step
# Epoch 234/500
# 26/26 - 0s - loss: 12.2100 - mean_absolute_error: 2.6028 - val_loss: 12.5866 - val_mean_absolute_error: 2.3710 - 98ms/epoch - 4ms/step
# Epoch 235/500
# 26/26 - 0s - loss: 12.0166 - mean_absolute_error: 2.4763 - val_loss: 13.9623 - val_mean_absolute_error: 2.5832 - 86ms/epoch - 3ms/step
# Epoch 236/500
# 26/26 - 0s - loss: 10.0872 - mean_absolute_error: 2.4012 - val_loss: 13.4257 - val_mean_absolute_error: 2.3423 - 90ms/epoch - 3ms/step
# Epoch 237/500
# 26/26 - 0s - loss: 12.9062 - mean_absolute_error: 2.5883 - val_loss: 15.7595 - val_mean_absolute_error: 2.6141 - 88ms/epoch - 3ms/step
# Epoch 238/500
# 26/26 - 0s - loss: 10.3362 - mean_absolute_error: 2.3784 - val_loss: 17.6408 - val_mean_absolute_error: 3.0012 - 92ms/epoch - 4ms/step
# Epoch 239/500
# 26/26 - 0s - loss: 13.9969 - mean_absolute_error: 2.6629 - val_loss: 14.4860 - val_mean_absolute_error: 2.5529 - 95ms/epoch - 4ms/step
# Epoch 240/500
# 26/26 - 0s - loss: 12.6328 - mean_absolute_error: 2.6206 - val_loss: 13.5620 - val_mean_absolute_error: 2.4467 - 97ms/epoch - 4ms/step
# Epoch 241/500
# 26/26 - 0s - loss: 12.1185 - mean_absolute_error: 2.5908 - val_loss: 14.5382 - val_mean_absolute_error: 2.4574 - 91ms/epoch - 3ms/step
# Epoch 242/500
# 26/26 - 0s - loss: 15.0134 - mean_absolute_error: 2.7206 - val_loss: 15.1982 - val_mean_absolute_error: 2.7851 - 87ms/epoch - 3ms/step
# Epoch 243/500
# 26/26 - 0s - loss: 13.4466 - mean_absolute_error: 2.5886 - val_loss: 14.8262 - val_mean_absolute_error: 2.6615 - 89ms/epoch - 3ms/step
# Epoch 244/500
# 26/26 - 0s - loss: 10.0588 - mean_absolute_error: 2.4323 - val_loss: 16.1855 - val_mean_absolute_error: 2.8239 - 91ms/epoch - 4ms/step
# Epoch 245/500
# 26/26 - 0s - loss: 11.0972 - mean_absolute_error: 2.5220 - val_loss: 13.7998 - val_mean_absolute_error: 2.2918 - 100ms/epoch - 4ms/step
# Epoch 246/500
# 26/26 - 0s - loss: 12.8845 - mean_absolute_error: 2.7315 - val_loss: 14.5209 - val_mean_absolute_error: 2.4778 - 91ms/epoch - 3ms/step
# Epoch 247/500
# 26/26 - 0s - loss: 12.2015 - mean_absolute_error: 2.5849 - val_loss: 14.4133 - val_mean_absolute_error: 2.3631 - 101ms/epoch - 4ms/step
# Epoch 248/500
# 26/26 - 0s - loss: 10.2484 - mean_absolute_error: 2.3595 - val_loss: 14.3529 - val_mean_absolute_error: 2.5521 - 88ms/epoch - 3ms/step
# Epoch 249/500
# 26/26 - 0s - loss: 12.0400 - mean_absolute_error: 2.5398 - val_loss: 13.2017 - val_mean_absolute_error: 2.2657 - 92ms/epoch - 4ms/step
# Epoch 250/500
# 26/26 - 0s - loss: 12.5331 - mean_absolute_error: 2.5106 - val_loss: 14.8290 - val_mean_absolute_error: 2.6981 - 96ms/epoch - 4ms/step
# Epoch 251/500
# 26/26 - 0s - loss: 12.8389 - mean_absolute_error: 2.5623 - val_loss: 13.8224 - val_mean_absolute_error: 2.3690 - 88ms/epoch - 3ms/step
# Epoch 252/500
# 26/26 - 0s - loss: 11.6639 - mean_absolute_error: 2.5573 - val_loss: 16.3405 - val_mean_absolute_error: 2.7994 - 87ms/epoch - 3ms/step
# Epoch 253/500
# 26/26 - 0s - loss: 11.6492 - mean_absolute_error: 2.5828 - val_loss: 16.2642 - val_mean_absolute_error: 2.8279 - 88ms/epoch - 3ms/step
# Epoch 254/500
# 26/26 - 0s - loss: 11.7525 - mean_absolute_error: 2.5517 - val_loss: 14.1151 - val_mean_absolute_error: 2.5958 - 88ms/epoch - 3ms/step
# Epoch 255/500
# 26/26 - 0s - loss: 11.8570 - mean_absolute_error: 2.5040 - val_loss: 12.4676 - val_mean_absolute_error: 2.2846 - 87ms/epoch - 3ms/step
# Epoch 256/500
# 26/26 - 0s - loss: 12.9680 - mean_absolute_error: 2.6855 - val_loss: 14.5522 - val_mean_absolute_error: 2.7063 - 87ms/epoch - 3ms/step
# Epoch 257/500
# 26/26 - 0s - loss: 13.2021 - mean_absolute_error: 2.6934 - val_loss: 13.3118 - val_mean_absolute_error: 2.5624 - 93ms/epoch - 4ms/step
# Epoch 258/500
# 26/26 - 0s - loss: 11.9693 - mean_absolute_error: 2.5698 - val_loss: 16.8292 - val_mean_absolute_error: 2.9377 - 96ms/epoch - 4ms/step
# Epoch 259/500
# 26/26 - 0s - loss: 12.7324 - mean_absolute_error: 2.6321 - val_loss: 16.2223 - val_mean_absolute_error: 2.4102 - 96ms/epoch - 4ms/step
# Epoch 260/500
# 26/26 - 0s - loss: 12.7388 - mean_absolute_error: 2.5347 - val_loss: 13.7499 - val_mean_absolute_error: 2.2894 - 113ms/epoch - 4ms/step
# Epoch 261/500
# 26/26 - 0s - loss: 10.9011 - mean_absolute_error: 2.4785 - val_loss: 13.2844 - val_mean_absolute_error: 2.2553 - 96ms/epoch - 4ms/step
# Epoch 262/500
# 26/26 - 0s - loss: 11.6319 - mean_absolute_error: 2.6043 - val_loss: 14.3184 - val_mean_absolute_error: 2.5761 - 100ms/epoch - 4ms/step
# Epoch 263/500
# 26/26 - 0s - loss: 12.7826 - mean_absolute_error: 2.6238 - val_loss: 13.9311 - val_mean_absolute_error: 2.4813 - 89ms/epoch - 3ms/step
# Epoch 264/500
# 26/26 - 0s - loss: 11.0432 - mean_absolute_error: 2.5050 - val_loss: 14.4500 - val_mean_absolute_error: 2.5050 - 89ms/epoch - 3ms/step
# Epoch 265/500
# 26/26 - 0s - loss: 11.9255 - mean_absolute_error: 2.5475 - val_loss: 13.3453 - val_mean_absolute_error: 2.4679 - 92ms/epoch - 4ms/step
# Epoch 266/500
# 26/26 - 0s - loss: 9.0256 - mean_absolute_error: 2.3177 - val_loss: 12.3199 - val_mean_absolute_error: 2.2981 - 99ms/epoch - 4ms/step
# Epoch 267/500
# 26/26 - 0s - loss: 10.6962 - mean_absolute_error: 2.3399 - val_loss: 12.6995 - val_mean_absolute_error: 2.1928 - 86ms/epoch - 3ms/step
# Epoch 268/500
# 26/26 - 0s - loss: 11.1496 - mean_absolute_error: 2.5253 - val_loss: 13.4679 - val_mean_absolute_error: 2.2870 - 96ms/epoch - 4ms/step
# Epoch 269/500
# 26/26 - 0s - loss: 12.9920 - mean_absolute_error: 2.5287 - val_loss: 14.0530 - val_mean_absolute_error: 2.5280 - 84ms/epoch - 3ms/step
# Epoch 270/500
# 26/26 - 0s - loss: 10.2309 - mean_absolute_error: 2.4618 - val_loss: 15.0313 - val_mean_absolute_error: 2.7398 - 93ms/epoch - 4ms/step
# Epoch 271/500
# 26/26 - 0s - loss: 12.6701 - mean_absolute_error: 2.6562 - val_loss: 18.8840 - val_mean_absolute_error: 3.2942 - 96ms/epoch - 4ms/step
# Epoch 272/500
# 26/26 - 0s - loss: 14.1829 - mean_absolute_error: 2.7084 - val_loss: 16.2290 - val_mean_absolute_error: 2.8974 - 98ms/epoch - 4ms/step
# Epoch 273/500
# 26/26 - 0s - loss: 10.8516 - mean_absolute_error: 2.4685 - val_loss: 13.8366 - val_mean_absolute_error: 2.6375 - 97ms/epoch - 4ms/step
# Epoch 274/500
# 26/26 - 0s - loss: 10.9223 - mean_absolute_error: 2.4875 - val_loss: 14.1328 - val_mean_absolute_error: 2.5456 - 89ms/epoch - 3ms/step
# Epoch 275/500
# 26/26 - 0s - loss: 13.1451 - mean_absolute_error: 2.5408 - val_loss: 12.9895 - val_mean_absolute_error: 2.3079 - 87ms/epoch - 3ms/step
# Epoch 276/500
# 26/26 - 0s - loss: 10.8872 - mean_absolute_error: 2.4164 - val_loss: 14.9153 - val_mean_absolute_error: 2.6511 - 89ms/epoch - 3ms/step
# Epoch 277/500
# 26/26 - 0s - loss: 12.3289 - mean_absolute_error: 2.4920 - val_loss: 16.2337 - val_mean_absolute_error: 2.7817 - 98ms/epoch - 4ms/step
# Epoch 278/500
# 26/26 - 0s - loss: 12.7035 - mean_absolute_error: 2.5597 - val_loss: 14.3348 - val_mean_absolute_error: 2.5601 - 90ms/epoch - 3ms/step
# Epoch 279/500
# 26/26 - 0s - loss: 11.0266 - mean_absolute_error: 2.5062 - val_loss: 12.6288 - val_mean_absolute_error: 2.2952 - 89ms/epoch - 3ms/step
# Epoch 280/500
# 26/26 - 0s - loss: 11.7088 - mean_absolute_error: 2.5619 - val_loss: 14.4116 - val_mean_absolute_error: 2.5449 - 94ms/epoch - 4ms/step
# Epoch 281/500
# 26/26 - 0s - loss: 12.6462 - mean_absolute_error: 2.6216 - val_loss: 13.7534 - val_mean_absolute_error: 2.4819 - 106ms/epoch - 4ms/step
# Epoch 282/500
# 26/26 - 0s - loss: 12.2905 - mean_absolute_error: 2.5689 - val_loss: 14.1011 - val_mean_absolute_error: 2.3209 - 88ms/epoch - 3ms/step
# Epoch 283/500
# 26/26 - 0s - loss: 10.7176 - mean_absolute_error: 2.4442 - val_loss: 14.7524 - val_mean_absolute_error: 2.6795 - 86ms/epoch - 3ms/step
# Epoch 284/500
# 26/26 - 0s - loss: 11.0880 - mean_absolute_error: 2.5101 - val_loss: 16.2462 - val_mean_absolute_error: 2.8637 - 88ms/epoch - 3ms/step
# Epoch 285/500
# 26/26 - 0s - loss: 11.2351 - mean_absolute_error: 2.5019 - val_loss: 14.7262 - val_mean_absolute_error: 2.3929 - 88ms/epoch - 3ms/step
# Epoch 286/500
# 26/26 - 0s - loss: 11.8078 - mean_absolute_error: 2.4961 - val_loss: 17.0087 - val_mean_absolute_error: 2.4488 - 90ms/epoch - 3ms/step
# Epoch 287/500
# 26/26 - 0s - loss: 11.5249 - mean_absolute_error: 2.4853 - val_loss: 14.6646 - val_mean_absolute_error: 2.3586 - 89ms/epoch - 3ms/step
# Epoch 288/500
# 26/26 - 0s - loss: 10.8905 - mean_absolute_error: 2.4969 - val_loss: 13.9184 - val_mean_absolute_error: 2.2761 - 90ms/epoch - 3ms/step
# Epoch 289/500
# 26/26 - 0s - loss: 10.1284 - mean_absolute_error: 2.4190 - val_loss: 14.9934 - val_mean_absolute_error: 2.6745 - 85ms/epoch - 3ms/step
# Epoch 290/500
# 26/26 - 0s - loss: 9.7330 - mean_absolute_error: 2.3643 - val_loss: 14.6553 - val_mean_absolute_error: 2.6987 - 88ms/epoch - 3ms/step
# Epoch 291/500
# 26/26 - 0s - loss: 9.0713 - mean_absolute_error: 2.3033 - val_loss: 12.3294 - val_mean_absolute_error: 2.2634 - 110ms/epoch - 4ms/step
# Epoch 292/500
# 26/26 - 0s - loss: 12.3998 - mean_absolute_error: 2.5107 - val_loss: 12.4730 - val_mean_absolute_error: 2.2302 - 105ms/epoch - 4ms/step
# Epoch 293/500
# 26/26 - 0s - loss: 12.3095 - mean_absolute_error: 2.5207 - val_loss: 12.8381 - val_mean_absolute_error: 2.2062 - 106ms/epoch - 4ms/step
# Epoch 294/500
# 26/26 - 0s - loss: 12.2788 - mean_absolute_error: 2.5868 - val_loss: 13.6059 - val_mean_absolute_error: 2.2811 - 88ms/epoch - 3ms/step
# Epoch 295/500
# 26/26 - 0s - loss: 11.3452 - mean_absolute_error: 2.4113 - val_loss: 14.1161 - val_mean_absolute_error: 2.4932 - 88ms/epoch - 3ms/step
# Epoch 296/500
# 26/26 - 0s - loss: 10.9598 - mean_absolute_error: 2.4162 - val_loss: 13.7596 - val_mean_absolute_error: 2.2672 - 101ms/epoch - 4ms/step
# Epoch 297/500
# 26/26 - 0s - loss: 11.8125 - mean_absolute_error: 2.5639 - val_loss: 14.0523 - val_mean_absolute_error: 2.4449 - 97ms/epoch - 4ms/step
# Epoch 298/500
# 26/26 - 0s - loss: 10.8913 - mean_absolute_error: 2.4277 - val_loss: 13.0594 - val_mean_absolute_error: 2.3803 - 88ms/epoch - 3ms/step
# Epoch 299/500
# 26/26 - 0s - loss: 10.0587 - mean_absolute_error: 2.3628 - val_loss: 12.8078 - val_mean_absolute_error: 2.4179 - 89ms/epoch - 3ms/step
# Epoch 300/500
# 26/26 - 0s - loss: 12.2957 - mean_absolute_error: 2.5102 - val_loss: 18.7381 - val_mean_absolute_error: 3.1372 - 87ms/epoch - 3ms/step
# Epoch 301/500
# 26/26 - 0s - loss: 10.5746 - mean_absolute_error: 2.4337 - val_loss: 14.4972 - val_mean_absolute_error: 2.4421 - 105ms/epoch - 4ms/step
# Epoch 302/500
# 26/26 - 0s - loss: 11.3008 - mean_absolute_error: 2.5375 - val_loss: 12.7008 - val_mean_absolute_error: 2.3561 - 89ms/epoch - 3ms/step
# Epoch 303/500
# 26/26 - 0s - loss: 11.9853 - mean_absolute_error: 2.4959 - val_loss: 13.6063 - val_mean_absolute_error: 2.3203 - 93ms/epoch - 4ms/step
# Epoch 304/500
# 26/26 - 0s - loss: 10.9520 - mean_absolute_error: 2.4458 - val_loss: 12.0178 - val_mean_absolute_error: 2.2371 - 86ms/epoch - 3ms/step
# Epoch 305/500
# 26/26 - 0s - loss: 11.1730 - mean_absolute_error: 2.4616 - val_loss: 11.8859 - val_mean_absolute_error: 2.2399 - 91ms/epoch - 4ms/step
# Epoch 306/500
# 26/26 - 0s - loss: 11.8082 - mean_absolute_error: 2.5059 - val_loss: 12.7660 - val_mean_absolute_error: 2.5153 - 98ms/epoch - 4ms/step
# Epoch 307/500
# 26/26 - 0s - loss: 10.1514 - mean_absolute_error: 2.3802 - val_loss: 12.3378 - val_mean_absolute_error: 2.3370 - 87ms/epoch - 3ms/step
# Epoch 308/500
# 26/26 - 0s - loss: 12.4636 - mean_absolute_error: 2.5250 - val_loss: 12.2106 - val_mean_absolute_error: 2.3029 - 88ms/epoch - 3ms/step
# Epoch 309/500
# 26/26 - 0s - loss: 11.7955 - mean_absolute_error: 2.5337 - val_loss: 13.4993 - val_mean_absolute_error: 2.5447 - 87ms/epoch - 3ms/step
# Epoch 310/500
# 26/26 - 0s - loss: 11.5886 - mean_absolute_error: 2.4921 - val_loss: 13.2145 - val_mean_absolute_error: 2.3635 - 91ms/epoch - 3ms/step
# Epoch 311/500
# 26/26 - 0s - loss: 12.3929 - mean_absolute_error: 2.5813 - val_loss: 13.6123 - val_mean_absolute_error: 2.5200 - 138ms/epoch - 5ms/step
# Epoch 312/500
# 26/26 - 0s - loss: 10.4813 - mean_absolute_error: 2.4286 - val_loss: 11.7273 - val_mean_absolute_error: 2.2507 - 87ms/epoch - 3ms/step
# Epoch 313/500
# 26/26 - 0s - loss: 11.4761 - mean_absolute_error: 2.4999 - val_loss: 11.5028 - val_mean_absolute_error: 2.1681 - 91ms/epoch - 3ms/step
# Epoch 314/500
# ...
# Epoch 395/500
# 26/26 - 0s - loss: 10.1740 - mean_absolute_error: 2.3022 - val_loss: 14.2088 - val_mean_absolute_error: 2.6263 - 90ms/epoch - 3ms/step
# Epoch 396/500
# 26/26 - 0s - loss: 10.3168 - mean_absolute_error: 2.3355 - val_loss: 12.6025 - val_mean_absolute_error: 2.3189 - 95ms/epoch - 4ms/step
# Epoch 397/500
# 26/26 - 0s - loss: 10.5197 - mean_absolute_error: 2.4176 - val_loss: 12.0437 - val_mean_absolute_error: 2.2850 - 88ms/epoch - 3ms/step
# Epoch 398/500
# 26/26 - 0s - loss: 12.3339 - mean_absolute_error: 2.6384 - val_loss: 12.5157 - val_mean_absolute_error: 2.1877 - 114ms/epoch - 4ms/step
# Epoch 399/500
# 26/26 - 0s - loss: 9.8309 - mean_absolute_error: 2.3389 - val_loss: 13.4311 - val_mean_absolute_error: 2.2974 - 88ms/epoch - 3ms/step
# Epoch 400/500
# 26/26 - 0s - loss: 8.2617 - mean_absolute_error: 2.1831 - val_loss: 11.9319 - val_mean_absolute_error: 2.1691 - 86ms/epoch - 3ms/step
# Epoch 401/500
# 26/26 - 0s - loss: 9.2804 - mean_absolute_error: 2.2390 - val_loss: 14.6305 - val_mean_absolute_error: 2.7375 - 87ms/epoch - 3ms/step
# Epoch 402/500
# 26/26 - 0s - loss: 7.7958 - mean_absolute_error: 2.1311 - val_loss: 13.0338 - val_mean_absolute_error: 2.5540 - 88ms/epoch - 3ms/step
# Epoch 403/500
# 26/26 - 0s - loss: 12.3213 - mean_absolute_error: 2.4975 - val_loss: 11.8643 - val_mean_absolute_error: 2.2808 - 95ms/epoch - 4ms/step
# Epoch 404/500
# 26/26 - 0s - loss: 11.1729 - mean_absolute_error: 2.3918 - val_loss: 12.4274 - val_mean_absolute_error: 2.3041 - 99ms/epoch - 4ms/step
# Epoch 405/500
# 26/26 - 0s - loss: 9.0556 - mean_absolute_error: 2.1620 - val_loss: 12.1205 - val_mean_absolute_error: 2.2820 - 96ms/epoch - 4ms/step
# Epoch 406/500
# 26/26 - 0s - loss: 9.4193 - mean_absolute_error: 2.2642 - val_loss: 13.1667 - val_mean_absolute_error: 2.5337 - 92ms/epoch - 4ms/step
# Epoch 407/500
# 26/26 - 0s - loss: 8.5342 - mean_absolute_error: 2.1969 - val_loss: 11.8360 - val_mean_absolute_error: 2.2831 - 92ms/epoch - 4ms/step
# Epoch 408/500
# 26/26 - 0s - loss: 9.9458 - mean_absolute_error: 2.2428 - val_loss: 13.3359 - val_mean_absolute_error: 2.5521 - 89ms/epoch - 3ms/step
# Epoch 409/500
# 26/26 - 0s - loss: 10.3110 - mean_absolute_error: 2.2968 - val_loss: 11.8801 - val_mean_absolute_error: 2.3246 - 91ms/epoch - 3ms/step
# Epoch 410/500
# 26/26 - 0s - loss: 8.6304 - mean_absolute_error: 2.1723 - val_loss: 14.3404 - val_mean_absolute_error: 2.6937 - 95ms/epoch - 4ms/step
# Epoch 411/500
# 26/26 - 0s - loss: 9.6814 - mean_absolute_error: 2.3578 - val_loss: 12.0725 - val_mean_absolute_error: 2.3093 - 99ms/epoch - 4ms/step
# Epoch 412/500
# 26/26 - 0s - loss: 9.0342 - mean_absolute_error: 2.2056 - val_loss: 12.3768 - val_mean_absolute_error: 2.4044 - 93ms/epoch - 4ms/step
# Epoch 413/500
# 26/26 - 0s - loss: 9.6000 - mean_absolute_error: 2.2697 - val_loss: 11.4755 - val_mean_absolute_error: 2.2473 - 92ms/epoch - 4ms/step
# Epoch 414/500
# 26/26 - 0s - loss: 11.8196 - mean_absolute_error: 2.4903 - val_loss: 11.7137 - val_mean_absolute_error: 2.2360 - 101ms/epoch - 4ms/step
# Epoch 415/500
# 26/26 - 0s - loss: 10.0787 - mean_absolute_error: 2.3367 - val_loss: 12.9927 - val_mean_absolute_error: 2.4191 - 96ms/epoch - 4ms/step
# Epoch 416/500
# 26/26 - 0s - loss: 7.9910 - mean_absolute_error: 2.1812 - val_loss: 14.6553 - val_mean_absolute_error: 2.7118 - 90ms/epoch - 3ms/step
# Epoch 417/500
# 26/26 - 0s - loss: 8.3445 - mean_absolute_error: 2.1453 - val_loss: 12.7442 - val_mean_absolute_error: 2.4164 - 101ms/epoch - 4ms/step
# Epoch 418/500
# 26/26 - 0s - loss: 8.9290 - mean_absolute_error: 2.2506 - val_loss: 14.3912 - val_mean_absolute_error: 2.5849 - 90ms/epoch - 3ms/step
# Epoch 419/500
# 26/26 - 0s - loss: 10.8051 - mean_absolute_error: 2.3802 - val_loss: 12.6237 - val_mean_absolute_error: 2.4097 - 98ms/epoch - 4ms/step
# Epoch 420/500
# 26/26 - 0s - loss: 10.4902 - mean_absolute_error: 2.3521 - val_loss: 12.3229 - val_mean_absolute_error: 2.1944 - 89ms/epoch - 3ms/step
# Epoch 421/500
# 26/26 - 0s - loss: 9.3173 - mean_absolute_error: 2.3206 - val_loss: 13.6885 - val_mean_absolute_error: 2.5173 - 95ms/epoch - 4ms/step
# Epoch 422/500
# 26/26 - 0s - loss: 10.4793 - mean_absolute_error: 2.3180 - val_loss: 11.6658 - val_mean_absolute_error: 2.3105 - 89ms/epoch - 3ms/step
# Epoch 423/500
# 26/26 - 0s - loss: 10.7468 - mean_absolute_error: 2.3535 - val_loss: 11.2094 - val_mean_absolute_error: 2.1399 - 89ms/epoch - 3ms/step
# Epoch 424/500
# 26/26 - 0s - loss: 10.0875 - mean_absolute_error: 2.3408 - val_loss: 11.4231 - val_mean_absolute_error: 2.2110 - 106ms/epoch - 4ms/step
# Epoch 425/500
# 26/26 - 0s - loss: 11.3945 - mean_absolute_error: 2.5018 - val_loss: 12.4701 - val_mean_absolute_error: 2.4606 - 89ms/epoch - 3ms/step
# Epoch 426/500
# 26/26 - 0s - loss: 9.9145 - mean_absolute_error: 2.2882 - val_loss: 12.6473 - val_mean_absolute_error: 2.4773 - 90ms/epoch - 3ms/step
# Epoch 427/500
# 26/26 - 0s - loss: 9.4250 - mean_absolute_error: 2.3197 - val_loss: 13.8330 - val_mean_absolute_error: 2.6417 - 91ms/epoch - 4ms/step
# Epoch 428/500
# 26/26 - 0s - loss: 11.6326 - mean_absolute_error: 2.4309 - val_loss: 20.0026 - val_mean_absolute_error: 3.2770 - 87ms/epoch - 3ms/step
# Epoch 429/500
# 26/26 - 0s - loss: 11.0812 - mean_absolute_error: 2.4091 - val_loss: 13.4352 - val_mean_absolute_error: 2.3273 - 93ms/epoch - 4ms/step
# Epoch 430/500
# 26/26 - 0s - loss: 7.6694 - mean_absolute_error: 2.1214 - val_loss: 13.2923 - val_mean_absolute_error: 2.4150 - 88ms/epoch - 3ms/step
# Epoch 431/500
# 26/26 - 0s - loss: 9.7490 - mean_absolute_error: 2.3302 - val_loss: 13.3506 - val_mean_absolute_error: 2.4121 - 88ms/epoch - 3ms/step
# Epoch 432/500
# 26/26 - 0s - loss: 9.4793 - mean_absolute_error: 2.2651 - val_loss: 14.4078 - val_mean_absolute_error: 2.7373 - 89ms/epoch - 3ms/step
# Epoch 433/500
# 26/26 - 0s - loss: 8.2632 - mean_absolute_error: 2.0979 - val_loss: 11.5999 - val_mean_absolute_error: 2.2548 - 88ms/epoch - 3ms/step
# Epoch 434/500
# 26/26 - 0s - loss: 8.9378 - mean_absolute_error: 2.2311 - val_loss: 13.1862 - val_mean_absolute_error: 2.5092 - 99ms/epoch - 4ms/step
# Epoch 435/500
# 26/26 - 0s - loss: 8.8153 - mean_absolute_error: 2.2309 - val_loss: 13.8375 - val_mean_absolute_error: 2.4923 - 95ms/epoch - 4ms/step
# Epoch 436/500
# 26/26 - 0s - loss: 8.9312 - mean_absolute_error: 2.2110 - val_loss: 13.3830 - val_mean_absolute_error: 2.3144 - 98ms/epoch - 4ms/step
# Epoch 437/500
# 26/26 - 0s - loss: 9.8942 - mean_absolute_error: 2.3311 - val_loss: 11.0370 - val_mean_absolute_error: 2.2720 - 95ms/epoch - 4ms/step
# Epoch 438/500
# 26/26 - 0s - loss: 11.9369 - mean_absolute_error: 2.5113 - val_loss: 11.1713 - val_mean_absolute_error: 2.3783 - 87ms/epoch - 3ms/step
# Epoch 439/500
# 26/26 - 0s - loss: 11.1746 - mean_absolute_error: 2.3831 - val_loss: 15.7521 - val_mean_absolute_error: 2.9280 - 89ms/epoch - 3ms/step
# Epoch 440/500
# 26/26 - 0s - loss: 11.2499 - mean_absolute_error: 2.3792 - val_loss: 13.0107 - val_mean_absolute_error: 2.4581 - 99ms/epoch - 4ms/step
# Epoch 441/500
# 26/26 - 0s - loss: 10.6502 - mean_absolute_error: 2.4442 - val_loss: 13.0704 - val_mean_absolute_error: 2.5396 - 85ms/epoch - 3ms/step
# Epoch 442/500
# 26/26 - 0s - loss: 10.7021 - mean_absolute_error: 2.3461 - val_loss: 13.5360 - val_mean_absolute_error: 2.5806 - 87ms/epoch - 3ms/step
# Epoch 443/500
# 26/26 - 0s - loss: 12.4501 - mean_absolute_error: 2.4526 - val_loss: 15.1204 - val_mean_absolute_error: 2.7375 - 88ms/epoch - 3ms/step
# Epoch 444/500
# 26/26 - 0s - loss: 10.8492 - mean_absolute_error: 2.4491 - val_loss: 16.6441 - val_mean_absolute_error: 2.8818 - 101ms/epoch - 4ms/step
# Epoch 445/500
# 26/26 - 0s - loss: 8.4966 - mean_absolute_error: 2.1897 - val_loss: 13.0115 - val_mean_absolute_error: 2.4872 - 100ms/epoch - 4ms/step
# Epoch 446/500
# 26/26 - 0s - loss: 8.0800 - mean_absolute_error: 2.1307 - val_loss: 11.4461 - val_mean_absolute_error: 2.2719 - 89ms/epoch - 3ms/step
# Epoch 447/500
# 26/26 - 0s - loss: 7.7561 - mean_absolute_error: 2.0750 - val_loss: 11.4334 - val_mean_absolute_error: 2.2586 - 87ms/epoch - 3ms/step
# Epoch 448/500
# 26/26 - 0s - loss: 8.1400 - mean_absolute_error: 2.1637 - val_loss: 11.4414 - val_mean_absolute_error: 2.2401 - 86ms/epoch - 3ms/step
# Epoch 449/500
# 26/26 - 0s - loss: 9.6999 - mean_absolute_error: 2.2968 - val_loss: 11.6027 - val_mean_absolute_error: 2.2179 - 87ms/epoch - 3ms/step
# Epoch 450/500
# 26/26 - 0s - loss: 8.7349 - mean_absolute_error: 2.1566 - val_loss: 12.2690 - val_mean_absolute_error: 2.3156 - 104ms/epoch - 4ms/step
# Epoch 451/500
# 26/26 - 0s - loss: 7.6400 - mean_absolute_error: 2.1116 - val_loss: 11.9277 - val_mean_absolute_error: 2.1385 - 88ms/epoch - 3ms/step
# Epoch 452/500
# 26/26 - 0s - loss: 9.5403 - mean_absolute_error: 2.2496 - val_loss: 13.3369 - val_mean_absolute_error: 2.4989 - 89ms/epoch - 3ms/step
# Epoch 453/500
# 26/26 - 0s - loss: 9.9480 - mean_absolute_error: 2.3857 - val_loss: 11.1105 - val_mean_absolute_error: 2.1977 - 99ms/epoch - 4ms/step
# Epoch 454/500
# 26/26 - 0s - loss: 10.6613 - mean_absolute_error: 2.3749 - val_loss: 10.6484 - val_mean_absolute_error: 2.1785 - 97ms/epoch - 4ms/step
# Epoch 455/500
# 26/26 - 0s - loss: 10.2137 - mean_absolute_error: 2.3653 - val_loss: 10.9023 - val_mean_absolute_error: 2.1400 - 102ms/epoch - 4ms/step
# Epoch 456/500
# 26/26 - 0s - loss: 9.3443 - mean_absolute_error: 2.2194 - val_loss: 14.0929 - val_mean_absolute_error: 2.6883 - 91ms/epoch - 3ms/step
# Epoch 457/500
# 26/26 - 0s - loss: 10.3015 - mean_absolute_error: 2.3949 - val_loss: 15.1905 - val_mean_absolute_error: 2.8398 - 102ms/epoch - 4ms/step
# Epoch 458/500
# 26/26 - 0s - loss: 10.9056 - mean_absolute_error: 2.4537 - val_loss: 18.3067 - val_mean_absolute_error: 3.2004 - 87ms/epoch - 3ms/step
# Epoch 459/500
# 26/26 - 0s - loss: 8.9298 - mean_absolute_error: 2.2136 - val_loss: 13.8651 - val_mean_absolute_error: 2.6384 - 90ms/epoch - 3ms/step
# Epoch 460/500
# 26/26 - 0s - loss: 10.4151 - mean_absolute_error: 2.3475 - val_loss: 15.0886 - val_mean_absolute_error: 2.8188 - 89ms/epoch - 3ms/step
# Epoch 461/500
# 26/26 - 0s - loss: 9.0649 - mean_absolute_error: 2.1952 - val_loss: 12.3848 - val_mean_absolute_error: 2.4108 - 89ms/epoch - 3ms/step
# Epoch 462/500
# 26/26 - 0s - loss: 8.3305 - mean_absolute_error: 2.2045 - val_loss: 12.7435 - val_mean_absolute_error: 2.4683 - 91ms/epoch - 4ms/step
# Epoch 463/500
# 26/26 - 0s - loss: 8.9669 - mean_absolute_error: 2.2158 - val_loss: 15.4129 - val_mean_absolute_error: 2.8094 - 98ms/epoch - 4ms/step
# Epoch 464/500
# 26/26 - 0s - loss: 7.4312 - mean_absolute_error: 2.0621 - val_loss: 12.1572 - val_mean_absolute_error: 2.3605 - 86ms/epoch - 3ms/step
# Epoch 465/500
# 26/26 - 0s - loss: 11.2092 - mean_absolute_error: 2.4062 - val_loss: 17.5355 - val_mean_absolute_error: 3.1063 - 97ms/epoch - 4ms/step
# Epoch 466/500
# 26/26 - 0s - loss: 9.3323 - mean_absolute_error: 2.2408 - val_loss: 13.7550 - val_mean_absolute_error: 2.6028 - 90ms/epoch - 3ms/step
# Epoch 467/500
# 26/26 - 0s - loss: 9.6571 - mean_absolute_error: 2.2775 - val_loss: 14.6683 - val_mean_absolute_error: 2.6948 - 90ms/epoch - 3ms/step
# Epoch 468/500
# 26/26 - 0s - loss: 9.7993 - mean_absolute_error: 2.3369 - val_loss: 11.8820 - val_mean_absolute_error: 2.2195 - 99ms/epoch - 4ms/step
# Epoch 469/500
# 26/26 - 0s - loss: 9.0391 - mean_absolute_error: 2.2818 - val_loss: 12.6872 - val_mean_absolute_error: 2.4690 - 101ms/epoch - 4ms/step
# Epoch 470/500
# 26/26 - 0s - loss: 9.2373 - mean_absolute_error: 2.3158 - val_loss: 10.9865 - val_mean_absolute_error: 2.2184 - 86ms/epoch - 3ms/step
# Epoch 471/500
# 26/26 - 0s - loss: 9.5932 - mean_absolute_error: 2.2657 - val_loss: 11.5263 - val_mean_absolute_error: 2.2580 - 89ms/epoch - 3ms/step
# Epoch 472/500
# 26/26 - 0s - loss: 8.6176 - mean_absolute_error: 2.1558 - val_loss: 12.0786 - val_mean_absolute_error: 2.1658 - 97ms/epoch - 4ms/step
# Epoch 473/500
# 26/26 - 0s - loss: 11.5038 - mean_absolute_error: 2.4730 - val_loss: 11.5458 - val_mean_absolute_error: 2.1676 - 88ms/epoch - 3ms/step
# Epoch 474/500
# 26/26 - 0s - loss: 8.4832 - mean_absolute_error: 2.2144 - val_loss: 12.6396 - val_mean_absolute_error: 2.5098 - 87ms/epoch - 3ms/step
# Epoch 475/500
# 26/26 - 0s - loss: 10.7295 - mean_absolute_error: 2.3922 - val_loss: 12.0352 - val_mean_absolute_error: 2.4511 - 106ms/epoch - 4ms/step
# Epoch 476/500
# 26/26 - 0s - loss: 9.2580 - mean_absolute_error: 2.3058 - val_loss: 10.6366 - val_mean_absolute_error: 2.1656 - 94ms/epoch - 4ms/step
# Epoch 477/500
# 26/26 - 0s - loss: 10.2409 - mean_absolute_error: 2.3342 - val_loss: 10.5788 - val_mean_absolute_error: 2.1970 - 90ms/epoch - 3ms/step
# Epoch 478/500
# 26/26 - 0s - loss: 11.9353 - mean_absolute_error: 2.4644 - val_loss: 17.4592 - val_mean_absolute_error: 3.1172 - 98ms/epoch - 4ms/step
# Epoch 479/500
# 26/26 - 0s - loss: 10.1013 - mean_absolute_error: 2.3279 - val_loss: 11.6736 - val_mean_absolute_error: 2.3147 - 92ms/epoch - 4ms/step
# Epoch 480/500
# 26/26 - 0s - loss: 11.0148 - mean_absolute_error: 2.4219 - val_loss: 11.8757 - val_mean_absolute_error: 2.3220 - 90ms/epoch - 3ms/step
# Epoch 481/500
# 26/26 - 0s - loss: 8.2646 - mean_absolute_error: 2.1922 - val_loss: 12.1219 - val_mean_absolute_error: 2.3394 - 92ms/epoch - 4ms/step
# Epoch 482/500
# 26/26 - 0s - loss: 8.5083 - mean_absolute_error: 2.1371 - val_loss: 12.9249 - val_mean_absolute_error: 2.4716 - 92ms/epoch - 4ms/step
# Epoch 483/500
# 26/26 - 0s - loss: 7.8975 - mean_absolute_error: 2.1097 - val_loss: 11.9135 - val_mean_absolute_error: 2.1631 - 88ms/epoch - 3ms/step
# Epoch 484/500
# 26/26 - 0s - loss: 8.6302 - mean_absolute_error: 2.1909 - val_loss: 13.1829 - val_mean_absolute_error: 2.5179 - 100ms/epoch - 4ms/step
# Epoch 485/500
# 26/26 - 0s - loss: 9.3344 - mean_absolute_error: 2.3025 - val_loss: 12.8589 - val_mean_absolute_error: 2.4632 - 93ms/epoch - 4ms/step
# Epoch 486/500
# 26/26 - 0s - loss: 7.9198 - mean_absolute_error: 2.1167 - val_loss: 12.3882 - val_mean_absolute_error: 2.4565 - 88ms/epoch - 3ms/step
# Epoch 487/500
# 26/26 - 0s - loss: 8.6495 - mean_absolute_error: 2.2697 - val_loss: 11.1246 - val_mean_absolute_error: 2.2733 - 109ms/epoch - 4ms/step
# Epoch 488/500
# 26/26 - 0s - loss: 9.5564 - mean_absolute_error: 2.2550 - val_loss: 10.5366 - val_mean_absolute_error: 2.1336 - 91ms/epoch - 4ms/step
# Epoch 489/500
# 26/26 - 0s - loss: 8.7687 - mean_absolute_error: 2.1662 - val_loss: 14.0793 - val_mean_absolute_error: 2.7279 - 100ms/epoch - 4ms/step
# Epoch 490/500
# 26/26 - 0s - loss: 9.8240 - mean_absolute_error: 2.2958 - val_loss: 13.2720 - val_mean_absolute_error: 2.5580 - 103ms/epoch - 4ms/step
# Epoch 491/500
# 26/26 - 0s - loss: 9.0603 - mean_absolute_error: 2.2967 - val_loss: 13.3850 - val_mean_absolute_error: 2.5731 - 98ms/epoch - 4ms/step
# Epoch 492/500
# 26/26 - 0s - loss: 8.1135 - mean_absolute_error: 2.1114 - val_loss: 11.5955 - val_mean_absolute_error: 2.2781 - 91ms/epoch - 3ms/step
# Epoch 493/500
# 26/26 - 0s - loss: 10.0861 - mean_absolute_error: 2.2821 - val_loss: 10.2527 - val_mean_absolute_error: 2.0386 - 88ms/epoch - 3ms/step
# Epoch 494/500
# 26/26 - 0s - loss: 10.6312 - mean_absolute_error: 2.3092 - val_loss: 11.2532 - val_mean_absolute_error: 2.1640 - 88ms/epoch - 3ms/step
# Epoch 495/500
# 26/26 - 0s - loss: 8.4456 - mean_absolute_error: 2.1920 - val_loss: 12.5024 - val_mean_absolute_error: 2.1927 - 95ms/epoch - 4ms/step
# Epoch 496/500
# 26/26 - 0s - loss: 9.1137 - mean_absolute_error: 2.1960 - val_loss: 14.3474 - val_mean_absolute_error: 2.7104 - 102ms/epoch - 4ms/step
# Epoch 497/500
# 26/26 - 0s - loss: 11.0289 - mean_absolute_error: 2.4253 - val_loss: 11.7599 - val_mean_absolute_error: 2.2610 - 98ms/epoch - 4ms/step
# Epoch 498/500
# 26/26 - 0s - loss: 8.6883 - mean_absolute_error: 2.1359 - val_loss: 11.7900 - val_mean_absolute_error: 2.3799 - 96ms/epoch - 4ms/step
# Epoch 499/500
# 26/26 - 0s - loss: 9.4934 - mean_absolute_error: 2.2376 - val_loss: 12.0641 - val_mean_absolute_error: 2.2327 - 89ms/epoch - 3ms/step
# Epoch 500/500
# 26/26 - 0s - loss: 8.9046 - mean_absolute_error: 2.2569 - val_loss: 11.6894 - val_mean_absolute_error: 2.2852 - 87ms/epoch - 3ms/step
# 4/4 [==============================] - 0s 5ms/step
# Prediction:  9.012726 , true value:  7.2
# Prediction:  18.970814 , true value:  18.8
# Prediction:  20.67868 , true value:  19.0
# Prediction:  31.16327 , true value:  27.0
