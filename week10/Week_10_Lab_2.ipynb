# %% [markdown]
# <a href="https://colab.research.google.com/github/ImAli0/ImAli/blob/main/week10/Week_10_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from tensorflow.keras import layers

model=keras.Sequential([layers.Dense(64, activation='relu'), layers.Dense(10,activation='softmax')])

# %%
model=keras.Sequential()
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10,activation='softmax'))

# %%
model.build(input_shape=(None,3))
model.weights
# Out:
# [<tf.Variable 'dense_4/kernel:0' shape=(3, 64) dtype=float32, numpy=
#  array([[-0.16001673, -0.01508471, -0.16327617,  0.09046319,  0.27152544,
#          -0.21183836, -0.14634214,  0.0828315 , -0.12550141,  0.25571132,
#           0.10030928, -0.24299273, -0.07919101, -0.04145315,  0.14927208,
#           0.03042376,  0.2227242 , -0.14441198,  0.17896077,  0.23500407,
#          -0.17146692, -0.18258956, -0.04842299,  0.16595292, -0.27426636,
#          -0.00313616,  0.14561746, -0.24741176,  0.26171833, -0.03736621,
#           0.19592288, -0.14096305,  0.11777413,  0.19806474, -0.12198335,
#           0.08021206,  0.03874508, -0.2809873 ,  0.139812  ,  0.06208134,
#          -0.14205973,  0.28326732, -0.03466901,  0.24088842,  0.29013038,
#          -0.26676512, -0.16919136,  0.28620863, -0.2720738 ,  0.22782397,
#          -0.02254936, -0.267106  ,  0.2564479 , -0.23316926,  0.08452022,
#          -0.25143877, -0.10453404,  0.20046195, -0.02408254,  0.23600721,
# ...

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 64)                256
#
#  dense_5 (Dense)             (None, 10)                650
#
# ...
# Total params: 906
# Trainable params: 906
# Non-trainable params: 0
# _________________________________________________________________
